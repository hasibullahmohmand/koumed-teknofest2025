# %%
import torch
from torch import nn, optim
from torch.utils.data import DataLoader
from torchvision import transforms
from torchvision.datasets import ImageFolder
from transformers import SwinForImageClassification
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, roc_auc_score, roc_curve
import seaborn as sns
import numpy as np

# %%
dataset_dir = '/kaggle/input/brainstroke2class/dataset'
torch.manual_seed(42)
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]) 
])

dataset = ImageFolder(root=dataset_dir, transform=transform)

# Split the dataset into train and validation sets (80% training, 20% validation)
train_size = int(0.8 * len(dataset))
val_size = len(dataset) - train_size
train_dataset, val_dataset = torch.utils.data.random_split(dataset, [train_size, val_size])

# %%
train_dataloader = DataLoader(train_dataset, batch_size=16, shuffle=True)
val_dataloader = DataLoader(val_dataset, batch_size=16, shuffle=False)

# %%
model = SwinForImageClassification.from_pretrained(
    "microsoft/swin-base-patch4-window7-224",
    num_labels=1,  # Your number of output classes
    ignore_mismatched_sizes=True  # This avoids the classifier output class mismatch error
)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
if torch.cuda.device_count() > 1:
    print(f"Using {torch.cuda.device_count()} GPUs!")
    model = nn.DataParallel(model)
model.to(device)
# Out:
# config.json:   0%|          | 0.00/71.8k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/352M [00:00<?, ?B/s]
# Some weights of SwinForImageClassification were not initialized from the model checkpoint at microsoft/swin-base-patch4-window7-224 and are newly initialized because the shapes did not match:
# - classifier.bias: found shape torch.Size([1000]) in the checkpoint and torch.Size([1]) in the model instantiated
# - classifier.weight: found shape torch.Size([1000, 1024]) in the checkpoint and torch.Size([1, 1024]) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Using 2 GPUs!
# DataParallel(
#   (module): SwinForImageClassification(
#     (swin): SwinModel(
#       (embeddings): SwinEmbeddings(
#         (patch_embeddings): SwinPatchEmbeddings(
#           (projection): Conv2d(3, 128, kernel_size=(4, 4), stride=(4, 4))
#         )
#         (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#       )
#       (encoder): SwinEncoder(
#         (layers): ModuleList(
#           (0): SwinStage(
#             (blocks): ModuleList(
#               (0): SwinLayer(
#                 (layernorm_before): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#                 (attention): SwinAttention(
#                   (self): SwinSelfAttention(
#                     (query): Linear(in_features=128, out_features=128, bias=True)
#                     (key): Linear(in_features=128, out_features=128, bias=True)
#                     (value): Linear(in_features=128, out_features=128, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                   (output): SwinSelfOutput(
#                     (dense): Linear(in_features=128, out_features=128, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                 )
#                 (drop_path): Identity()
#                 (layernorm_after): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#                 (intermediate): SwinIntermediate(
#                   (dense): Linear(in_features=128, out_features=512, bias=True)
#                   (intermediate_act_fn): GELUActivation()
#                 )
#                 (output): SwinOutput(
#                   (dense): Linear(in_features=512, out_features=128, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (1): SwinLayer(
#                 (layernorm_before): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#                 (attention): SwinAttention(
#                   (self): SwinSelfAttention(
#                     (query): Linear(in_features=128, out_features=128, bias=True)
#                     (key): Linear(in_features=128, out_features=128, bias=True)
#                     (value): Linear(in_features=128, out_features=128, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                   (output): SwinSelfOutput(
#                     (dense): Linear(in_features=128, out_features=128, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                 )
#                 (drop_path): SwinDropPath(p=0.004347826354205608)
#                 (layernorm_after): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#                 (intermediate): SwinIntermediate(
#                   (dense): Linear(in_features=128, out_features=512, bias=True)
#                   (intermediate_act_fn): GELUActivation()
#                 )
#                 (output): SwinOutput(
#                   (dense): Linear(in_features=512, out_features=128, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#             )
#             (downsample): SwinPatchMerging(
#               (reduction): Linear(in_features=512, out_features=256, bias=False)
#               (norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             )
#           )
#           (1): SwinStage(
#             (blocks): ModuleList(
#               (0): SwinLayer(
#                 (layernorm_before): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#                 (attention): SwinAttention(
#                   (self): SwinSelfAttention(
#                     (query): Linear(in_features=256, out_features=256, bias=True)
#                     (key): Linear(in_features=256, out_features=256, bias=True)
#                     (value): Linear(in_features=256, out_features=256, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                   (output): SwinSelfOutput(
#                     (dense): Linear(in_features=256, out_features=256, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                 )
#                 (drop_path): SwinDropPath(p=0.008695652708411217)
#                 (layernorm_after): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#                 (intermediate): SwinIntermediate(
#                   (dense): Linear(in_features=256, out_features=1024, bias=True)
#                   (intermediate_act_fn): GELUActivation()
#                 )
#                 (output): SwinOutput(
#                   (dense): Linear(in_features=1024, out_features=256, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (1): SwinLayer(
#                 (layernorm_before): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#                 (attention): SwinAttention(
#                   (self): SwinSelfAttention(
#                     (query): Linear(in_features=256, out_features=256, bias=True)
#                     (key): Linear(in_features=256, out_features=256, bias=True)
#                     (value): Linear(in_features=256, out_features=256, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                   (output): SwinSelfOutput(
#                     (dense): Linear(in_features=256, out_features=256, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                 )
#                 (drop_path): SwinDropPath(p=0.013043479062616825)
#                 (layernorm_after): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#                 (intermediate): SwinIntermediate(
#                   (dense): Linear(in_features=256, out_features=1024, bias=True)
#                   (intermediate_act_fn): GELUActivation()
#                 )
#                 (output): SwinOutput(
#                   (dense): Linear(in_features=1024, out_features=256, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#             )
#             (downsample): SwinPatchMerging(
#               (reduction): Linear(in_features=1024, out_features=512, bias=False)
#               (norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#             )
#           )
#           (2): SwinStage(
#             (blocks): ModuleList(
#               (0): SwinLayer(
#                 (layernorm_before): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#                 (attention): SwinAttention(
#                   (self): SwinSelfAttention(
#                     (query): Linear(in_features=512, out_features=512, bias=True)
#                     (key): Linear(in_features=512, out_features=512, bias=True)
#                     (value): Linear(in_features=512, out_features=512, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                   (output): SwinSelfOutput(
#                     (dense): Linear(in_features=512, out_features=512, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                 )
#                 (drop_path): SwinDropPath(p=0.017391305416822433)
#                 (layernorm_after): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#                 (intermediate): SwinIntermediate(
#                   (dense): Linear(in_features=512, out_features=2048, bias=True)
#                   (intermediate_act_fn): GELUActivation()
#                 )
#                 (output): SwinOutput(
#                   (dense): Linear(in_features=2048, out_features=512, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (1): SwinLayer(
#                 (layernorm_before): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#                 (attention): SwinAttention(
#                   (self): SwinSelfAttention(
#                     (query): Linear(in_features=512, out_features=512, bias=True)
#                     (key): Linear(in_features=512, out_features=512, bias=True)
#                     (value): Linear(in_features=512, out_features=512, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                   (output): SwinSelfOutput(
#                     (dense): Linear(in_features=512, out_features=512, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                 )
#                 (drop_path): SwinDropPath(p=0.021739132702350616)
#                 (layernorm_after): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#                 (intermediate): SwinIntermediate(
#                   (dense): Linear(in_features=512, out_features=2048, bias=True)
#                   (intermediate_act_fn): GELUActivation()
#                 )
#                 (output): SwinOutput(
#                   (dense): Linear(in_features=2048, out_features=512, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (2): SwinLayer(
#                 (layernorm_before): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#                 (attention): SwinAttention(
#                   (self): SwinSelfAttention(
#                     (query): Linear(in_features=512, out_features=512, bias=True)
#                     (key): Linear(in_features=512, out_features=512, bias=True)
#                     (value): Linear(in_features=512, out_features=512, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                   (output): SwinSelfOutput(
#                     (dense): Linear(in_features=512, out_features=512, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                 )
#                 (drop_path): SwinDropPath(p=0.02608695812523365)
#                 (layernorm_after): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#                 (intermediate): SwinIntermediate(
#                   (dense): Linear(in_features=512, out_features=2048, bias=True)
#                   (intermediate_act_fn): GELUActivation()
#                 )
#                 (output): SwinOutput(
#                   (dense): Linear(in_features=2048, out_features=512, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (3): SwinLayer(
#                 (layernorm_before): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#                 (attention): SwinAttention(
#                   (self): SwinSelfAttention(
#                     (query): Linear(in_features=512, out_features=512, bias=True)
#                     (key): Linear(in_features=512, out_features=512, bias=True)
#                     (value): Linear(in_features=512, out_features=512, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                   (output): SwinSelfOutput(
#                     (dense): Linear(in_features=512, out_features=512, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                 )
#                 (drop_path): SwinDropPath(p=0.030434783548116684)
#                 (layernorm_after): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#                 (intermediate): SwinIntermediate(
#                   (dense): Linear(in_features=512, out_features=2048, bias=True)
#                   (intermediate_act_fn): GELUActivation()
#                 )
#                 (output): SwinOutput(
#                   (dense): Linear(in_features=2048, out_features=512, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (4): SwinLayer(
#                 (layernorm_before): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#                 (attention): SwinAttention(
#                   (self): SwinSelfAttention(
#                     (query): Linear(in_features=512, out_features=512, bias=True)
#                     (key): Linear(in_features=512, out_features=512, bias=True)
#                     (value): Linear(in_features=512, out_features=512, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                   (output): SwinSelfOutput(
#                     (dense): Linear(in_features=512, out_features=512, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                 )
#                 (drop_path): SwinDropPath(p=0.03478261083364487)
#                 (layernorm_after): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#                 (intermediate): SwinIntermediate(
#                   (dense): Linear(in_features=512, out_features=2048, bias=True)
#                   (intermediate_act_fn): GELUActivation()
#                 )
#                 (output): SwinOutput(
#                   (dense): Linear(in_features=2048, out_features=512, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (5): SwinLayer(
#                 (layernorm_before): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#                 (attention): SwinAttention(
#                   (self): SwinSelfAttention(
#                     (query): Linear(in_features=512, out_features=512, bias=True)
#                     (key): Linear(in_features=512, out_features=512, bias=True)
#                     (value): Linear(in_features=512, out_features=512, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                   (output): SwinSelfOutput(
#                     (dense): Linear(in_features=512, out_features=512, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                 )
#                 (drop_path): SwinDropPath(p=0.03913043811917305)
#                 (layernorm_after): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#                 (intermediate): SwinIntermediate(
#                   (dense): Linear(in_features=512, out_features=2048, bias=True)
#                   (intermediate_act_fn): GELUActivation()
#                 )
#                 (output): SwinOutput(
#                   (dense): Linear(in_features=2048, out_features=512, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (6): SwinLayer(
#                 (layernorm_before): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#                 (attention): SwinAttention(
#                   (self): SwinSelfAttention(
#                     (query): Linear(in_features=512, out_features=512, bias=True)
#                     (key): Linear(in_features=512, out_features=512, bias=True)
#                     (value): Linear(in_features=512, out_features=512, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                   (output): SwinSelfOutput(
#                     (dense): Linear(in_features=512, out_features=512, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                 )
#                 (drop_path): SwinDropPath(p=0.04347826540470123)
#                 (layernorm_after): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#                 (intermediate): SwinIntermediate(
#                   (dense): Linear(in_features=512, out_features=2048, bias=True)
#                   (intermediate_act_fn): GELUActivation()
#                 )
#                 (output): SwinOutput(
#                   (dense): Linear(in_features=2048, out_features=512, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (7): SwinLayer(
#                 (layernorm_before): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#                 (attention): SwinAttention(
#                   (self): SwinSelfAttention(
#                     (query): Linear(in_features=512, out_features=512, bias=True)
#                     (key): Linear(in_features=512, out_features=512, bias=True)
#                     (value): Linear(in_features=512, out_features=512, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                   (output): SwinSelfOutput(
#                     (dense): Linear(in_features=512, out_features=512, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                 )
#                 (drop_path): SwinDropPath(p=0.04782608896493912)
#                 (layernorm_after): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#                 (intermediate): SwinIntermediate(
#                   (dense): Linear(in_features=512, out_features=2048, bias=True)
#                   (intermediate_act_fn): GELUActivation()
#                 )
#                 (output): SwinOutput(
#                   (dense): Linear(in_features=2048, out_features=512, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (8): SwinLayer(
#                 (layernorm_before): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#                 (attention): SwinAttention(
#                   (self): SwinSelfAttention(
#                     (query): Linear(in_features=512, out_features=512, bias=True)
#                     (key): Linear(in_features=512, out_features=512, bias=True)
#                     (value): Linear(in_features=512, out_features=512, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                   (output): SwinSelfOutput(
#                     (dense): Linear(in_features=512, out_features=512, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                 )
#                 (drop_path): SwinDropPath(p=0.052173912525177)
#                 (layernorm_after): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#                 (intermediate): SwinIntermediate(
#                   (dense): Linear(in_features=512, out_features=2048, bias=True)
#                   (intermediate_act_fn): GELUActivation()
#                 )
#                 (output): SwinOutput(
#                   (dense): Linear(in_features=2048, out_features=512, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (9): SwinLayer(
#                 (layernorm_before): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#                 (attention): SwinAttention(
#                   (self): SwinSelfAttention(
#                     (query): Linear(in_features=512, out_features=512, bias=True)
#                     (key): Linear(in_features=512, out_features=512, bias=True)
#                     (value): Linear(in_features=512, out_features=512, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                   (output): SwinSelfOutput(
#                     (dense): Linear(in_features=512, out_features=512, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                 )
#                 (drop_path): SwinDropPath(p=0.056521736085414886)
#                 (layernorm_after): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#                 (intermediate): SwinIntermediate(
#                   (dense): Linear(in_features=512, out_features=2048, bias=True)
#                   (intermediate_act_fn): GELUActivation()
#                 )
#                 (output): SwinOutput(
#                   (dense): Linear(in_features=2048, out_features=512, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (10): SwinLayer(
#                 (layernorm_before): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#                 (attention): SwinAttention(
#                   (self): SwinSelfAttention(
#                     (query): Linear(in_features=512, out_features=512, bias=True)
#                     (key): Linear(in_features=512, out_features=512, bias=True)
#                     (value): Linear(in_features=512, out_features=512, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                   (output): SwinSelfOutput(
#                     (dense): Linear(in_features=512, out_features=512, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                 )
#                 (drop_path): SwinDropPath(p=0.06086956337094307)
#                 (layernorm_after): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#                 (intermediate): SwinIntermediate(
#                   (dense): Linear(in_features=512, out_features=2048, bias=True)
#                   (intermediate_act_fn): GELUActivation()
#                 )
#                 (output): SwinOutput(
#                   (dense): Linear(in_features=2048, out_features=512, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (11): SwinLayer(
#                 (layernorm_before): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#                 (attention): SwinAttention(
#                   (self): SwinSelfAttention(
#                     (query): Linear(in_features=512, out_features=512, bias=True)
#                     (key): Linear(in_features=512, out_features=512, bias=True)
#                     (value): Linear(in_features=512, out_features=512, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                   (output): SwinSelfOutput(
#                     (dense): Linear(in_features=512, out_features=512, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                 )
#                 (drop_path): SwinDropPath(p=0.06521739065647125)
#                 (layernorm_after): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#                 (intermediate): SwinIntermediate(
#                   (dense): Linear(in_features=512, out_features=2048, bias=True)
#                   (intermediate_act_fn): GELUActivation()
#                 )
#                 (output): SwinOutput(
#                   (dense): Linear(in_features=2048, out_features=512, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (12): SwinLayer(
#                 (layernorm_before): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#                 (attention): SwinAttention(
#                   (self): SwinSelfAttention(
#                     (query): Linear(in_features=512, out_features=512, bias=True)
#                     (key): Linear(in_features=512, out_features=512, bias=True)
#                     (value): Linear(in_features=512, out_features=512, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                   (output): SwinSelfOutput(
#                     (dense): Linear(in_features=512, out_features=512, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                 )
#                 (drop_path): SwinDropPath(p=0.06956521421670914)
#                 (layernorm_after): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#                 (intermediate): SwinIntermediate(
#                   (dense): Linear(in_features=512, out_features=2048, bias=True)
#                   (intermediate_act_fn): GELUActivation()
#                 )
#                 (output): SwinOutput(
#                   (dense): Linear(in_features=2048, out_features=512, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (13): SwinLayer(
#                 (layernorm_before): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#                 (attention): SwinAttention(
#                   (self): SwinSelfAttention(
#                     (query): Linear(in_features=512, out_features=512, bias=True)
#                     (key): Linear(in_features=512, out_features=512, bias=True)
#                     (value): Linear(in_features=512, out_features=512, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                   (output): SwinSelfOutput(
#                     (dense): Linear(in_features=512, out_features=512, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                 )
#                 (drop_path): SwinDropPath(p=0.07391304522752762)
#                 (layernorm_after): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#                 (intermediate): SwinIntermediate(
#                   (dense): Linear(in_features=512, out_features=2048, bias=True)
#                   (intermediate_act_fn): GELUActivation()
#                 )
#                 (output): SwinOutput(
#                   (dense): Linear(in_features=2048, out_features=512, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (14): SwinLayer(
#                 (layernorm_before): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#                 (attention): SwinAttention(
#                   (self): SwinSelfAttention(
#                     (query): Linear(in_features=512, out_features=512, bias=True)
#                     (key): Linear(in_features=512, out_features=512, bias=True)
#                     (value): Linear(in_features=512, out_features=512, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                   (output): SwinSelfOutput(
#                     (dense): Linear(in_features=512, out_features=512, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                 )
#                 (drop_path): SwinDropPath(p=0.0782608687877655)
#                 (layernorm_after): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#                 (intermediate): SwinIntermediate(
#                   (dense): Linear(in_features=512, out_features=2048, bias=True)
#                   (intermediate_act_fn): GELUActivation()
#                 )
#                 (output): SwinOutput(
#                   (dense): Linear(in_features=2048, out_features=512, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (15): SwinLayer(
#                 (layernorm_before): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#                 (attention): SwinAttention(
#                   (self): SwinSelfAttention(
#                     (query): Linear(in_features=512, out_features=512, bias=True)
#                     (key): Linear(in_features=512, out_features=512, bias=True)
#                     (value): Linear(in_features=512, out_features=512, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                   (output): SwinSelfOutput(
#                     (dense): Linear(in_features=512, out_features=512, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                 )
#                 (drop_path): SwinDropPath(p=0.08260869979858398)
#                 (layernorm_after): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#                 (intermediate): SwinIntermediate(
#                   (dense): Linear(in_features=512, out_features=2048, bias=True)
#                   (intermediate_act_fn): GELUActivation()
#                 )
#                 (output): SwinOutput(
#                   (dense): Linear(in_features=2048, out_features=512, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (16): SwinLayer(
#                 (layernorm_before): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#                 (attention): SwinAttention(
#                   (self): SwinSelfAttention(
#                     (query): Linear(in_features=512, out_features=512, bias=True)
#                     (key): Linear(in_features=512, out_features=512, bias=True)
#                     (value): Linear(in_features=512, out_features=512, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                   (output): SwinSelfOutput(
#                     (dense): Linear(in_features=512, out_features=512, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                 )
#                 (drop_path): SwinDropPath(p=0.08695652335882187)
#                 (layernorm_after): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#                 (intermediate): SwinIntermediate(
#                   (dense): Linear(in_features=512, out_features=2048, bias=True)
#                   (intermediate_act_fn): GELUActivation()
#                 )
#                 (output): SwinOutput(
#                   (dense): Linear(in_features=2048, out_features=512, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (17): SwinLayer(
#                 (layernorm_before): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#                 (attention): SwinAttention(
#                   (self): SwinSelfAttention(
#                     (query): Linear(in_features=512, out_features=512, bias=True)
#                     (key): Linear(in_features=512, out_features=512, bias=True)
#                     (value): Linear(in_features=512, out_features=512, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                   (output): SwinSelfOutput(
#                     (dense): Linear(in_features=512, out_features=512, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                 )
#                 (drop_path): SwinDropPath(p=0.09130434691905975)
#                 (layernorm_after): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#                 (intermediate): SwinIntermediate(
#                   (dense): Linear(in_features=512, out_features=2048, bias=True)
#                   (intermediate_act_fn): GELUActivation()
#                 )
#                 (output): SwinOutput(
#                   (dense): Linear(in_features=2048, out_features=512, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#             )
#             (downsample): SwinPatchMerging(
#               (reduction): Linear(in_features=2048, out_features=1024, bias=False)
#               (norm): LayerNorm((2048,), eps=1e-05, elementwise_affine=True)
#             )
#           )
#           (3): SwinStage(
#             (blocks): ModuleList(
#               (0): SwinLayer(
#                 (layernorm_before): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#                 (attention): SwinAttention(
#                   (self): SwinSelfAttention(
#                     (query): Linear(in_features=1024, out_features=1024, bias=True)
#                     (key): Linear(in_features=1024, out_features=1024, bias=True)
#                     (value): Linear(in_features=1024, out_features=1024, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                   (output): SwinSelfOutput(
#                     (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                 )
#                 (drop_path): SwinDropPath(p=0.09565217792987823)
#                 (layernorm_after): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#                 (intermediate): SwinIntermediate(
#                   (dense): Linear(in_features=1024, out_features=4096, bias=True)
#                   (intermediate_act_fn): GELUActivation()
#                 )
#                 (output): SwinOutput(
#                   (dense): Linear(in_features=4096, out_features=1024, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (1): SwinLayer(
#                 (layernorm_before): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#                 (attention): SwinAttention(
#                   (self): SwinSelfAttention(
#                     (query): Linear(in_features=1024, out_features=1024, bias=True)
#                     (key): Linear(in_features=1024, out_features=1024, bias=True)
#                     (value): Linear(in_features=1024, out_features=1024, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                   (output): SwinSelfOutput(
#                     (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                 )
#                 (drop_path): SwinDropPath(p=0.10000000149011612)
#                 (layernorm_after): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#                 (intermediate): SwinIntermediate(
#                   (dense): Linear(in_features=1024, out_features=4096, bias=True)
#                   (intermediate_act_fn): GELUActivation()
#                 )
#                 (output): SwinOutput(
#                   (dense): Linear(in_features=4096, out_features=1024, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#             )
#           )
#         )
#       )
#       (layernorm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#       (pooler): AdaptiveAvgPool1d(output_size=1)
#     )
#     (classifier): Linear(in_features=1024, out_features=1, bias=True)
#   )
# )

# %%
print(model)
# Out:
# DataParallel(
#   (module): SwinForImageClassification(
#     (swin): SwinModel(
#       (embeddings): SwinEmbeddings(
#         (patch_embeddings): SwinPatchEmbeddings(
#           (projection): Conv2d(3, 128, kernel_size=(4, 4), stride=(4, 4))
#         )
#         (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#       )
#       (encoder): SwinEncoder(
#         (layers): ModuleList(
#           (0): SwinStage(
#             (blocks): ModuleList(
#               (0): SwinLayer(
#                 (layernorm_before): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#                 (attention): SwinAttention(
#                   (self): SwinSelfAttention(
#                     (query): Linear(in_features=128, out_features=128, bias=True)
#                     (key): Linear(in_features=128, out_features=128, bias=True)
#                     (value): Linear(in_features=128, out_features=128, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                   (output): SwinSelfOutput(
#                     (dense): Linear(in_features=128, out_features=128, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                 )
#                 (drop_path): Identity()
#                 (layernorm_after): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#                 (intermediate): SwinIntermediate(
#                   (dense): Linear(in_features=128, out_features=512, bias=True)
#                   (intermediate_act_fn): GELUActivation()
#                 )
#                 (output): SwinOutput(
#                   (dense): Linear(in_features=512, out_features=128, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (1): SwinLayer(
#                 (layernorm_before): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#                 (attention): SwinAttention(
#                   (self): SwinSelfAttention(
#                     (query): Linear(in_features=128, out_features=128, bias=True)
#                     (key): Linear(in_features=128, out_features=128, bias=True)
#                     (value): Linear(in_features=128, out_features=128, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                   (output): SwinSelfOutput(
#                     (dense): Linear(in_features=128, out_features=128, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                 )
#                 (drop_path): SwinDropPath(p=0.004347826354205608)
#                 (layernorm_after): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#                 (intermediate): SwinIntermediate(
#                   (dense): Linear(in_features=128, out_features=512, bias=True)
#                   (intermediate_act_fn): GELUActivation()
#                 )
#                 (output): SwinOutput(
#                   (dense): Linear(in_features=512, out_features=128, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#             )
#             (downsample): SwinPatchMerging(
#               (reduction): Linear(in_features=512, out_features=256, bias=False)
#               (norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             )
#           )
#           (1): SwinStage(
#             (blocks): ModuleList(
#               (0): SwinLayer(
#                 (layernorm_before): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#                 (attention): SwinAttention(
#                   (self): SwinSelfAttention(
#                     (query): Linear(in_features=256, out_features=256, bias=True)
#                     (key): Linear(in_features=256, out_features=256, bias=True)
#                     (value): Linear(in_features=256, out_features=256, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                   (output): SwinSelfOutput(
#                     (dense): Linear(in_features=256, out_features=256, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                 )
#                 (drop_path): SwinDropPath(p=0.008695652708411217)
#                 (layernorm_after): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#                 (intermediate): SwinIntermediate(
#                   (dense): Linear(in_features=256, out_features=1024, bias=True)
#                   (intermediate_act_fn): GELUActivation()
#                 )
#                 (output): SwinOutput(
#                   (dense): Linear(in_features=1024, out_features=256, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (1): SwinLayer(
#                 (layernorm_before): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#                 (attention): SwinAttention(
#                   (self): SwinSelfAttention(
#                     (query): Linear(in_features=256, out_features=256, bias=True)
#                     (key): Linear(in_features=256, out_features=256, bias=True)
#                     (value): Linear(in_features=256, out_features=256, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                   (output): SwinSelfOutput(
#                     (dense): Linear(in_features=256, out_features=256, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                 )
#                 (drop_path): SwinDropPath(p=0.013043479062616825)
#                 (layernorm_after): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#                 (intermediate): SwinIntermediate(
#                   (dense): Linear(in_features=256, out_features=1024, bias=True)
#                   (intermediate_act_fn): GELUActivation()
#                 )
#                 (output): SwinOutput(
#                   (dense): Linear(in_features=1024, out_features=256, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#             )
#             (downsample): SwinPatchMerging(
#               (reduction): Linear(in_features=1024, out_features=512, bias=False)
#               (norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#             )
#           )
#           (2): SwinStage(
#             (blocks): ModuleList(
#               (0): SwinLayer(
#                 (layernorm_before): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#                 (attention): SwinAttention(
#                   (self): SwinSelfAttention(
#                     (query): Linear(in_features=512, out_features=512, bias=True)
#                     (key): Linear(in_features=512, out_features=512, bias=True)
#                     (value): Linear(in_features=512, out_features=512, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                   (output): SwinSelfOutput(
#                     (dense): Linear(in_features=512, out_features=512, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                 )
#                 (drop_path): SwinDropPath(p=0.017391305416822433)
#                 (layernorm_after): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#                 (intermediate): SwinIntermediate(
#                   (dense): Linear(in_features=512, out_features=2048, bias=True)
#                   (intermediate_act_fn): GELUActivation()
#                 )
#                 (output): SwinOutput(
#                   (dense): Linear(in_features=2048, out_features=512, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (1): SwinLayer(
#                 (layernorm_before): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#                 (attention): SwinAttention(
#                   (self): SwinSelfAttention(
#                     (query): Linear(in_features=512, out_features=512, bias=True)
#                     (key): Linear(in_features=512, out_features=512, bias=True)
#                     (value): Linear(in_features=512, out_features=512, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                   (output): SwinSelfOutput(
#                     (dense): Linear(in_features=512, out_features=512, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                 )
#                 (drop_path): SwinDropPath(p=0.021739132702350616)
#                 (layernorm_after): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#                 (intermediate): SwinIntermediate(
#                   (dense): Linear(in_features=512, out_features=2048, bias=True)
#                   (intermediate_act_fn): GELUActivation()
#                 )
#                 (output): SwinOutput(
#                   (dense): Linear(in_features=2048, out_features=512, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (2): SwinLayer(
#                 (layernorm_before): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#                 (attention): SwinAttention(
#                   (self): SwinSelfAttention(
#                     (query): Linear(in_features=512, out_features=512, bias=True)
#                     (key): Linear(in_features=512, out_features=512, bias=True)
#                     (value): Linear(in_features=512, out_features=512, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                   (output): SwinSelfOutput(
#                     (dense): Linear(in_features=512, out_features=512, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                 )
#                 (drop_path): SwinDropPath(p=0.02608695812523365)
#                 (layernorm_after): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#                 (intermediate): SwinIntermediate(
#                   (dense): Linear(in_features=512, out_features=2048, bias=True)
#                   (intermediate_act_fn): GELUActivation()
#                 )
#                 (output): SwinOutput(
#                   (dense): Linear(in_features=2048, out_features=512, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (3): SwinLayer(
#                 (layernorm_before): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#                 (attention): SwinAttention(
#                   (self): SwinSelfAttention(
#                     (query): Linear(in_features=512, out_features=512, bias=True)
#                     (key): Linear(in_features=512, out_features=512, bias=True)
#                     (value): Linear(in_features=512, out_features=512, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                   (output): SwinSelfOutput(
#                     (dense): Linear(in_features=512, out_features=512, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                 )
#                 (drop_path): SwinDropPath(p=0.030434783548116684)
#                 (layernorm_after): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#                 (intermediate): SwinIntermediate(
#                   (dense): Linear(in_features=512, out_features=2048, bias=True)
#                   (intermediate_act_fn): GELUActivation()
#                 )
#                 (output): SwinOutput(
#                   (dense): Linear(in_features=2048, out_features=512, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (4): SwinLayer(
#                 (layernorm_before): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#                 (attention): SwinAttention(
#                   (self): SwinSelfAttention(
#                     (query): Linear(in_features=512, out_features=512, bias=True)
#                     (key): Linear(in_features=512, out_features=512, bias=True)
#                     (value): Linear(in_features=512, out_features=512, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                   (output): SwinSelfOutput(
#                     (dense): Linear(in_features=512, out_features=512, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                 )
#                 (drop_path): SwinDropPath(p=0.03478261083364487)
#                 (layernorm_after): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#                 (intermediate): SwinIntermediate(
#                   (dense): Linear(in_features=512, out_features=2048, bias=True)
#                   (intermediate_act_fn): GELUActivation()
#                 )
#                 (output): SwinOutput(
#                   (dense): Linear(in_features=2048, out_features=512, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (5): SwinLayer(
#                 (layernorm_before): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#                 (attention): SwinAttention(
#                   (self): SwinSelfAttention(
#                     (query): Linear(in_features=512, out_features=512, bias=True)
#                     (key): Linear(in_features=512, out_features=512, bias=True)
#                     (value): Linear(in_features=512, out_features=512, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                   (output): SwinSelfOutput(
#                     (dense): Linear(in_features=512, out_features=512, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                 )
#                 (drop_path): SwinDropPath(p=0.03913043811917305)
#                 (layernorm_after): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#                 (intermediate): SwinIntermediate(
#                   (dense): Linear(in_features=512, out_features=2048, bias=True)
#                   (intermediate_act_fn): GELUActivation()
#                 )
#                 (output): SwinOutput(
#                   (dense): Linear(in_features=2048, out_features=512, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (6): SwinLayer(
#                 (layernorm_before): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#                 (attention): SwinAttention(
#                   (self): SwinSelfAttention(
#                     (query): Linear(in_features=512, out_features=512, bias=True)
#                     (key): Linear(in_features=512, out_features=512, bias=True)
#                     (value): Linear(in_features=512, out_features=512, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                   (output): SwinSelfOutput(
#                     (dense): Linear(in_features=512, out_features=512, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                 )
#                 (drop_path): SwinDropPath(p=0.04347826540470123)
#                 (layernorm_after): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#                 (intermediate): SwinIntermediate(
#                   (dense): Linear(in_features=512, out_features=2048, bias=True)
#                   (intermediate_act_fn): GELUActivation()
#                 )
#                 (output): SwinOutput(
#                   (dense): Linear(in_features=2048, out_features=512, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (7): SwinLayer(
#                 (layernorm_before): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#                 (attention): SwinAttention(
#                   (self): SwinSelfAttention(
#                     (query): Linear(in_features=512, out_features=512, bias=True)
#                     (key): Linear(in_features=512, out_features=512, bias=True)
#                     (value): Linear(in_features=512, out_features=512, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                   (output): SwinSelfOutput(
#                     (dense): Linear(in_features=512, out_features=512, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                 )
#                 (drop_path): SwinDropPath(p=0.04782608896493912)
#                 (layernorm_after): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#                 (intermediate): SwinIntermediate(
#                   (dense): Linear(in_features=512, out_features=2048, bias=True)
#                   (intermediate_act_fn): GELUActivation()
#                 )
#                 (output): SwinOutput(
#                   (dense): Linear(in_features=2048, out_features=512, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (8): SwinLayer(
#                 (layernorm_before): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#                 (attention): SwinAttention(
#                   (self): SwinSelfAttention(
#                     (query): Linear(in_features=512, out_features=512, bias=True)
#                     (key): Linear(in_features=512, out_features=512, bias=True)
#                     (value): Linear(in_features=512, out_features=512, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                   (output): SwinSelfOutput(
#                     (dense): Linear(in_features=512, out_features=512, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                 )
#                 (drop_path): SwinDropPath(p=0.052173912525177)
#                 (layernorm_after): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#                 (intermediate): SwinIntermediate(
#                   (dense): Linear(in_features=512, out_features=2048, bias=True)
#                   (intermediate_act_fn): GELUActivation()
#                 )
#                 (output): SwinOutput(
#                   (dense): Linear(in_features=2048, out_features=512, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (9): SwinLayer(
#                 (layernorm_before): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#                 (attention): SwinAttention(
#                   (self): SwinSelfAttention(
#                     (query): Linear(in_features=512, out_features=512, bias=True)
#                     (key): Linear(in_features=512, out_features=512, bias=True)
#                     (value): Linear(in_features=512, out_features=512, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                   (output): SwinSelfOutput(
#                     (dense): Linear(in_features=512, out_features=512, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                 )
#                 (drop_path): SwinDropPath(p=0.056521736085414886)
#                 (layernorm_after): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#                 (intermediate): SwinIntermediate(
#                   (dense): Linear(in_features=512, out_features=2048, bias=True)
#                   (intermediate_act_fn): GELUActivation()
#                 )
#                 (output): SwinOutput(
#                   (dense): Linear(in_features=2048, out_features=512, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (10): SwinLayer(
#                 (layernorm_before): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#                 (attention): SwinAttention(
#                   (self): SwinSelfAttention(
#                     (query): Linear(in_features=512, out_features=512, bias=True)
#                     (key): Linear(in_features=512, out_features=512, bias=True)
#                     (value): Linear(in_features=512, out_features=512, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                   (output): SwinSelfOutput(
#                     (dense): Linear(in_features=512, out_features=512, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                 )
#                 (drop_path): SwinDropPath(p=0.06086956337094307)
#                 (layernorm_after): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#                 (intermediate): SwinIntermediate(
#                   (dense): Linear(in_features=512, out_features=2048, bias=True)
#                   (intermediate_act_fn): GELUActivation()
#                 )
#                 (output): SwinOutput(
#                   (dense): Linear(in_features=2048, out_features=512, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (11): SwinLayer(
#                 (layernorm_before): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#                 (attention): SwinAttention(
#                   (self): SwinSelfAttention(
#                     (query): Linear(in_features=512, out_features=512, bias=True)
#                     (key): Linear(in_features=512, out_features=512, bias=True)
#                     (value): Linear(in_features=512, out_features=512, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                   (output): SwinSelfOutput(
#                     (dense): Linear(in_features=512, out_features=512, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                 )
#                 (drop_path): SwinDropPath(p=0.06521739065647125)
#                 (layernorm_after): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#                 (intermediate): SwinIntermediate(
#                   (dense): Linear(in_features=512, out_features=2048, bias=True)
#                   (intermediate_act_fn): GELUActivation()
#                 )
#                 (output): SwinOutput(
#                   (dense): Linear(in_features=2048, out_features=512, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (12): SwinLayer(
#                 (layernorm_before): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#                 (attention): SwinAttention(
#                   (self): SwinSelfAttention(
#                     (query): Linear(in_features=512, out_features=512, bias=True)
#                     (key): Linear(in_features=512, out_features=512, bias=True)
#                     (value): Linear(in_features=512, out_features=512, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                   (output): SwinSelfOutput(
#                     (dense): Linear(in_features=512, out_features=512, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                 )
#                 (drop_path): SwinDropPath(p=0.06956521421670914)
#                 (layernorm_after): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#                 (intermediate): SwinIntermediate(
#                   (dense): Linear(in_features=512, out_features=2048, bias=True)
#                   (intermediate_act_fn): GELUActivation()
#                 )
#                 (output): SwinOutput(
#                   (dense): Linear(in_features=2048, out_features=512, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (13): SwinLayer(
#                 (layernorm_before): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#                 (attention): SwinAttention(
#                   (self): SwinSelfAttention(
#                     (query): Linear(in_features=512, out_features=512, bias=True)
#                     (key): Linear(in_features=512, out_features=512, bias=True)
#                     (value): Linear(in_features=512, out_features=512, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                   (output): SwinSelfOutput(
#                     (dense): Linear(in_features=512, out_features=512, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                 )
#                 (drop_path): SwinDropPath(p=0.07391304522752762)
#                 (layernorm_after): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#                 (intermediate): SwinIntermediate(
#                   (dense): Linear(in_features=512, out_features=2048, bias=True)
#                   (intermediate_act_fn): GELUActivation()
#                 )
#                 (output): SwinOutput(
#                   (dense): Linear(in_features=2048, out_features=512, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (14): SwinLayer(
#                 (layernorm_before): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#                 (attention): SwinAttention(
#                   (self): SwinSelfAttention(
#                     (query): Linear(in_features=512, out_features=512, bias=True)
#                     (key): Linear(in_features=512, out_features=512, bias=True)
#                     (value): Linear(in_features=512, out_features=512, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                   (output): SwinSelfOutput(
#                     (dense): Linear(in_features=512, out_features=512, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                 )
#                 (drop_path): SwinDropPath(p=0.0782608687877655)
#                 (layernorm_after): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#                 (intermediate): SwinIntermediate(
#                   (dense): Linear(in_features=512, out_features=2048, bias=True)
#                   (intermediate_act_fn): GELUActivation()
#                 )
#                 (output): SwinOutput(
#                   (dense): Linear(in_features=2048, out_features=512, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (15): SwinLayer(
#                 (layernorm_before): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#                 (attention): SwinAttention(
#                   (self): SwinSelfAttention(
#                     (query): Linear(in_features=512, out_features=512, bias=True)
#                     (key): Linear(in_features=512, out_features=512, bias=True)
#                     (value): Linear(in_features=512, out_features=512, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                   (output): SwinSelfOutput(
#                     (dense): Linear(in_features=512, out_features=512, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                 )
#                 (drop_path): SwinDropPath(p=0.08260869979858398)
#                 (layernorm_after): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#                 (intermediate): SwinIntermediate(
#                   (dense): Linear(in_features=512, out_features=2048, bias=True)
#                   (intermediate_act_fn): GELUActivation()
#                 )
#                 (output): SwinOutput(
#                   (dense): Linear(in_features=2048, out_features=512, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (16): SwinLayer(
#                 (layernorm_before): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#                 (attention): SwinAttention(
#                   (self): SwinSelfAttention(
#                     (query): Linear(in_features=512, out_features=512, bias=True)
#                     (key): Linear(in_features=512, out_features=512, bias=True)
#                     (value): Linear(in_features=512, out_features=512, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                   (output): SwinSelfOutput(
#                     (dense): Linear(in_features=512, out_features=512, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                 )
#                 (drop_path): SwinDropPath(p=0.08695652335882187)
#                 (layernorm_after): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#                 (intermediate): SwinIntermediate(
#                   (dense): Linear(in_features=512, out_features=2048, bias=True)
#                   (intermediate_act_fn): GELUActivation()
#                 )
#                 (output): SwinOutput(
#                   (dense): Linear(in_features=2048, out_features=512, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (17): SwinLayer(
#                 (layernorm_before): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#                 (attention): SwinAttention(
#                   (self): SwinSelfAttention(
#                     (query): Linear(in_features=512, out_features=512, bias=True)
#                     (key): Linear(in_features=512, out_features=512, bias=True)
#                     (value): Linear(in_features=512, out_features=512, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                   (output): SwinSelfOutput(
#                     (dense): Linear(in_features=512, out_features=512, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                 )
#                 (drop_path): SwinDropPath(p=0.09130434691905975)
#                 (layernorm_after): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#                 (intermediate): SwinIntermediate(
#                   (dense): Linear(in_features=512, out_features=2048, bias=True)
#                   (intermediate_act_fn): GELUActivation()
#                 )
#                 (output): SwinOutput(
#                   (dense): Linear(in_features=2048, out_features=512, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#             )
#             (downsample): SwinPatchMerging(
#               (reduction): Linear(in_features=2048, out_features=1024, bias=False)
#               (norm): LayerNorm((2048,), eps=1e-05, elementwise_affine=True)
#             )
#           )
#           (3): SwinStage(
#             (blocks): ModuleList(
#               (0): SwinLayer(
#                 (layernorm_before): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#                 (attention): SwinAttention(
#                   (self): SwinSelfAttention(
#                     (query): Linear(in_features=1024, out_features=1024, bias=True)
#                     (key): Linear(in_features=1024, out_features=1024, bias=True)
#                     (value): Linear(in_features=1024, out_features=1024, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                   (output): SwinSelfOutput(
#                     (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                 )
#                 (drop_path): SwinDropPath(p=0.09565217792987823)
#                 (layernorm_after): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#                 (intermediate): SwinIntermediate(
#                   (dense): Linear(in_features=1024, out_features=4096, bias=True)
#                   (intermediate_act_fn): GELUActivation()
#                 )
#                 (output): SwinOutput(
#                   (dense): Linear(in_features=4096, out_features=1024, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (1): SwinLayer(
#                 (layernorm_before): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#                 (attention): SwinAttention(
#                   (self): SwinSelfAttention(
#                     (query): Linear(in_features=1024, out_features=1024, bias=True)
#                     (key): Linear(in_features=1024, out_features=1024, bias=True)
#                     (value): Linear(in_features=1024, out_features=1024, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                   (output): SwinSelfOutput(
#                     (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                     (dropout): Dropout(p=0.0, inplace=False)
#                   )
#                 )
#                 (drop_path): SwinDropPath(p=0.10000000149011612)
#                 (layernorm_after): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#                 (intermediate): SwinIntermediate(
#                   (dense): Linear(in_features=1024, out_features=4096, bias=True)
#                   (intermediate_act_fn): GELUActivation()
#                 )
#                 (output): SwinOutput(
#                   (dense): Linear(in_features=4096, out_features=1024, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#             )
#           )
#         )
#       )
#       (layernorm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#       (pooler): AdaptiveAvgPool1d(output_size=1)
#     )
#     (classifier): Linear(in_features=1024, out_features=1, bias=True)
#   )
# )

# %%
for param in model.module.swin.parameters():
    param.requires_grad = False
for param in model.module.classifier.parameters():
    param.requires_grad = True

# %%
optimizer = optim.Adam([
    {'params': model.module.swin.parameters(), 'lr': 5e-5},  
    {'params': model.module.classifier.parameters(), 'lr': 1e-3} 
])
criterion = nn.BCEWithLogitsLoss()

# %%
train_losses = []
val_losses = []
train_accuracies = []
val_accuracies = []
epochs = 100
# Training loop
for epoch in range(epochs):
    model.train()  # Set model to training mode
    running_train_loss = 0.0
    correct_train = 0
    total_train = 0

    # Iterate through training data
    for inputs, labels in train_dataloader:
        inputs, labels = inputs.cuda(), labels.cuda()  # Move data to GPU

        # Zero the parameter gradients
        optimizer.zero_grad()

        # Forward pass
        outputs = model(inputs)
        loss = criterion(outputs.logits.squeeze(), labels.float())

        # Backward pass
        loss.backward()
        optimizer.step()

        # Track running loss
        running_train_loss += loss.item()

        # Track accuracy
        predicted = (torch.sigmoid(outputs.logits.squeeze()) > 0.5).long()
        total_train += labels.size(0)
        correct_train += (predicted == labels).sum().item()

    # Average training loss and accuracy for this epoch
    avg_train_loss = running_train_loss / len(train_dataloader)
    train_losses.append(avg_train_loss)
    train_accuracy = 100 * correct_train / total_train
    train_accuracies.append(train_accuracy)
    
    # Validation loop
    model.eval()  # Set model to evaluation mode
    running_val_loss = 0.0
    correct_val = 0
    total_val = 0

    with torch.no_grad():
        for inputs, labels in val_dataloader:
            inputs, labels = inputs.cuda(), labels.cuda()  # Move data to GPU

            # Forward pass
            outputs = model(inputs)
            loss = criterion(outputs.logits.squeeze(), labels.float())

            running_val_loss += loss.item()

            # Track validation accuracy
            predicted = (torch.sigmoid(outputs.logits.squeeze()) > 0.5).long()
            total_val += labels.size(0)
            correct_val += (predicted == labels).sum().item()

 # Average validation loss and accuracy for this epoch
    avg_val_loss = running_val_loss / len(val_dataloader)
    val_losses.append(avg_val_loss)
    val_accuracy = 100 * correct_val / total_val
    val_accuracies.append(val_accuracy)

    # Print epoch stats
    print(f'Epoch [{epoch+1}/{epochs}], '
          f'Train Loss: {avg_train_loss:.4f}, Train Accuracy: {train_accuracy:.2f}%, '
          f'Validation Loss: {avg_val_loss:.4f}, Validation Accuracy: {val_accuracy:.2f}%')
# Out:
# Epoch [1/100], Train Loss: 0.4903, Train Accuracy: 77.01%, Validation Loss: 0.4277, Validation Accuracy: 82.78%
# Epoch [2/100], Train Loss: 0.4058, Train Accuracy: 81.99%, Validation Loss: 0.4271, Validation Accuracy: 80.30%
# Epoch [3/100], Train Loss: 0.3817, Train Accuracy: 83.46%, Validation Loss: 0.3791, Validation Accuracy: 84.51%
# Epoch [4/100], Train Loss: 0.3630, Train Accuracy: 84.51%, Validation Loss: 0.3800, Validation Accuracy: 84.14%
# Epoch [5/100], Train Loss: 0.3442, Train Accuracy: 85.39%, Validation Loss: 0.3866, Validation Accuracy: 82.78%
# Epoch [6/100], Train Loss: 0.3359, Train Accuracy: 85.39%, Validation Loss: 0.3559, Validation Accuracy: 85.79%
# Epoch [7/100], Train Loss: 0.3307, Train Accuracy: 85.81%, Validation Loss: 0.3449, Validation Accuracy: 86.02%
# Epoch [8/100], Train Loss: 0.3224, Train Accuracy: 86.45%, Validation Loss: 0.3604, Validation Accuracy: 84.21%
# Epoch [9/100], Train Loss: 0.3171, Train Accuracy: 86.50%, Validation Loss: 0.3430, Validation Accuracy: 85.64%
# Epoch [10/100], Train Loss: 0.3079, Train Accuracy: 87.46%, Validation Loss: 0.3385, Validation Accuracy: 85.71%
# Epoch [11/100], Train Loss: 0.3063, Train Accuracy: 86.88%, Validation Loss: 0.3348, Validation Accuracy: 86.39%
# Epoch [12/100], Train Loss: 0.2996, Train Accuracy: 87.27%, Validation Loss: 0.3321, Validation Accuracy: 86.77%
# Epoch [13/100], Train Loss: 0.2993, Train Accuracy: 87.12%, Validation Loss: 0.3269, Validation Accuracy: 86.62%
# Epoch [14/100], Train Loss: 0.2976, Train Accuracy: 87.56%, Validation Loss: 0.3367, Validation Accuracy: 85.41%
# Epoch [15/100], Train Loss: 0.2926, Train Accuracy: 87.88%, Validation Loss: 0.3280, Validation Accuracy: 86.69%
# Epoch [16/100], Train Loss: 0.2902, Train Accuracy: 87.73%, Validation Loss: 0.3251, Validation Accuracy: 86.77%
# Epoch [17/100], Train Loss: 0.2871, Train Accuracy: 88.27%, Validation Loss: 0.3261, Validation Accuracy: 86.54%
# Epoch [18/100], Train Loss: 0.2817, Train Accuracy: 88.55%, Validation Loss: 0.3427, Validation Accuracy: 85.26%
# Epoch [19/100], Train Loss: 0.2837, Train Accuracy: 88.20%, Validation Loss: 0.3197, Validation Accuracy: 87.07%
# Epoch [20/100], Train Loss: 0.2826, Train Accuracy: 87.95%, Validation Loss: 0.3606, Validation Accuracy: 84.89%
# Epoch [21/100], Train Loss: 0.2753, Train Accuracy: 88.53%, Validation Loss: 0.3393, Validation Accuracy: 85.79%
# Epoch [22/100], Train Loss: 0.2822, Train Accuracy: 88.05%, Validation Loss: 0.3196, Validation Accuracy: 86.47%
# Epoch [23/100], Train Loss: 0.2776, Train Accuracy: 88.63%, Validation Loss: 0.3424, Validation Accuracy: 85.49%
# Epoch [24/100], Train Loss: 0.2693, Train Accuracy: 88.91%, Validation Loss: 0.3372, Validation Accuracy: 84.66%
# Epoch [25/100], Train Loss: 0.2734, Train Accuracy: 88.91%, Validation Loss: 0.3151, Validation Accuracy: 87.52%
# Epoch [26/100], Train Loss: 0.2683, Train Accuracy: 89.10%, Validation Loss: 0.3180, Validation Accuracy: 86.99%
# Epoch [27/100], Train Loss: 0.2728, Train Accuracy: 88.46%, Validation Loss: 0.3308, Validation Accuracy: 85.79%
# Epoch [28/100], Train Loss: 0.2671, Train Accuracy: 89.23%, Validation Loss: 0.3411, Validation Accuracy: 85.64%
# Epoch [29/100], Train Loss: 0.2629, Train Accuracy: 89.00%, Validation Loss: 0.3306, Validation Accuracy: 86.54%
# Epoch [30/100], Train Loss: 0.2594, Train Accuracy: 89.04%, Validation Loss: 0.3105, Validation Accuracy: 86.99%
# Epoch [31/100], Train Loss: 0.2630, Train Accuracy: 89.30%, Validation Loss: 0.3086, Validation Accuracy: 86.99%
# Epoch [32/100], Train Loss: 0.2583, Train Accuracy: 89.70%, Validation Loss: 0.3080, Validation Accuracy: 87.07%
# Epoch [33/100], Train Loss: 0.2636, Train Accuracy: 88.87%, Validation Loss: 0.3104, Validation Accuracy: 86.77%
# Epoch [34/100], Train Loss: 0.2540, Train Accuracy: 89.68%, Validation Loss: 0.3057, Validation Accuracy: 87.29%
# Epoch [35/100], Train Loss: 0.2557, Train Accuracy: 89.27%, Validation Loss: 0.3158, Validation Accuracy: 86.32%
# Epoch [36/100], Train Loss: 0.2568, Train Accuracy: 89.53%, Validation Loss: 0.3154, Validation Accuracy: 86.32%
# Epoch [37/100], Train Loss: 0.2575, Train Accuracy: 89.44%, Validation Loss: 0.3096, Validation Accuracy: 86.84%
# Epoch [38/100], Train Loss: 0.2549, Train Accuracy: 89.38%, Validation Loss: 0.3096, Validation Accuracy: 87.07%
# Epoch [39/100], Train Loss: 0.2509, Train Accuracy: 90.13%, Validation Loss: 0.3118, Validation Accuracy: 86.54%
# Epoch [40/100], Train Loss: 0.2510, Train Accuracy: 89.61%, Validation Loss: 0.3032, Validation Accuracy: 86.84%
# Epoch [41/100], Train Loss: 0.2598, Train Accuracy: 89.00%, Validation Loss: 0.3122, Validation Accuracy: 87.14%
# Epoch [42/100], Train Loss: 0.2529, Train Accuracy: 89.62%, Validation Loss: 0.3262, Validation Accuracy: 86.39%
# Epoch [43/100], Train Loss: 0.2489, Train Accuracy: 89.96%, Validation Loss: 0.3013, Validation Accuracy: 86.69%
# Epoch [44/100], Train Loss: 0.2485, Train Accuracy: 89.89%, Validation Loss: 0.3016, Validation Accuracy: 87.14%
# Epoch [45/100], Train Loss: 0.2523, Train Accuracy: 89.53%, Validation Loss: 0.3084, Validation Accuracy: 86.99%
# Epoch [46/100], Train Loss: 0.2522, Train Accuracy: 89.81%, Validation Loss: 0.3018, Validation Accuracy: 87.37%
# Epoch [47/100], Train Loss: 0.2496, Train Accuracy: 89.44%, Validation Loss: 0.3011, Validation Accuracy: 87.07%
# Epoch [48/100], Train Loss: 0.2504, Train Accuracy: 90.04%, Validation Loss: 0.3004, Validation Accuracy: 86.84%
# Epoch [49/100], Train Loss: 0.2432, Train Accuracy: 90.13%, Validation Loss: 0.3053, Validation Accuracy: 87.59%
# Epoch [50/100], Train Loss: 0.2436, Train Accuracy: 90.17%, Validation Loss: 0.3250, Validation Accuracy: 86.09%
# Epoch [51/100], Train Loss: 0.2433, Train Accuracy: 90.13%, Validation Loss: 0.3069, Validation Accuracy: 86.92%
# Epoch [52/100], Train Loss: 0.2435, Train Accuracy: 90.39%, Validation Loss: 0.3027, Validation Accuracy: 86.99%
# Epoch [53/100], Train Loss: 0.2407, Train Accuracy: 90.32%, Validation Loss: 0.3080, Validation Accuracy: 86.92%
# Epoch [54/100], Train Loss: 0.2458, Train Accuracy: 90.43%, Validation Loss: 0.2998, Validation Accuracy: 86.69%
# Epoch [55/100], Train Loss: 0.2435, Train Accuracy: 90.30%, Validation Loss: 0.3047, Validation Accuracy: 86.99%
# Epoch [56/100], Train Loss: 0.2445, Train Accuracy: 89.89%, Validation Loss: 0.3095, Validation Accuracy: 86.99%
# Epoch [57/100], Train Loss: 0.2412, Train Accuracy: 90.62%, Validation Loss: 0.3120, Validation Accuracy: 86.69%
# Epoch [58/100], Train Loss: 0.2397, Train Accuracy: 90.21%, Validation Loss: 0.3037, Validation Accuracy: 87.22%
# Epoch [59/100], Train Loss: 0.2382, Train Accuracy: 90.11%, Validation Loss: 0.3034, Validation Accuracy: 87.52%
# Epoch [60/100], Train Loss: 0.2423, Train Accuracy: 90.24%, Validation Loss: 0.2987, Validation Accuracy: 87.89%
# Epoch [61/100], Train Loss: 0.2398, Train Accuracy: 90.23%, Validation Loss: 0.2981, Validation Accuracy: 87.29%
# Epoch [62/100], Train Loss: 0.2336, Train Accuracy: 90.79%, Validation Loss: 0.3247, Validation Accuracy: 86.17%
# Epoch [63/100], Train Loss: 0.2364, Train Accuracy: 90.75%, Validation Loss: 0.2979, Validation Accuracy: 87.59%
# Epoch [64/100], Train Loss: 0.2348, Train Accuracy: 90.70%, Validation Loss: 0.3021, Validation Accuracy: 86.77%
# Epoch [65/100], Train Loss: 0.2336, Train Accuracy: 91.07%, Validation Loss: 0.2984, Validation Accuracy: 87.14%
# Epoch [66/100], Train Loss: 0.2378, Train Accuracy: 90.32%, Validation Loss: 0.3005, Validation Accuracy: 86.77%
# Epoch [67/100], Train Loss: 0.2374, Train Accuracy: 90.55%, Validation Loss: 0.3164, Validation Accuracy: 87.14%
# Epoch [68/100], Train Loss: 0.2341, Train Accuracy: 90.49%, Validation Loss: 0.2996, Validation Accuracy: 87.14%
# Epoch [69/100], Train Loss: 0.2378, Train Accuracy: 90.66%, Validation Loss: 0.2961, Validation Accuracy: 88.12%
# Epoch [70/100], Train Loss: 0.2306, Train Accuracy: 90.60%, Validation Loss: 0.2971, Validation Accuracy: 87.44%
# Epoch [71/100], Train Loss: 0.2303, Train Accuracy: 91.05%, Validation Loss: 0.3044, Validation Accuracy: 87.14%
# Epoch [72/100], Train Loss: 0.2401, Train Accuracy: 90.51%, Validation Loss: 0.2997, Validation Accuracy: 87.22%
# Epoch [73/100], Train Loss: 0.2346, Train Accuracy: 90.73%, Validation Loss: 0.3008, Validation Accuracy: 86.77%
# Epoch [74/100], Train Loss: 0.2337, Train Accuracy: 91.03%, Validation Loss: 0.3050, Validation Accuracy: 87.22%
# Epoch [75/100], Train Loss: 0.2283, Train Accuracy: 90.96%, Validation Loss: 0.3043, Validation Accuracy: 87.29%
# Epoch [76/100], Train Loss: 0.2314, Train Accuracy: 90.79%, Validation Loss: 0.3119, Validation Accuracy: 86.69%
# Epoch [77/100], Train Loss: 0.2323, Train Accuracy: 90.58%, Validation Loss: 0.3064, Validation Accuracy: 87.14%
# Epoch [78/100], Train Loss: 0.2259, Train Accuracy: 91.24%, Validation Loss: 0.3109, Validation Accuracy: 86.54%
# Epoch [79/100], Train Loss: 0.2273, Train Accuracy: 91.30%, Validation Loss: 0.2987, Validation Accuracy: 87.07%
# Epoch [80/100], Train Loss: 0.2291, Train Accuracy: 91.15%, Validation Loss: 0.3063, Validation Accuracy: 86.84%
# Epoch [81/100], Train Loss: 0.2258, Train Accuracy: 90.83%, Validation Loss: 0.3040, Validation Accuracy: 87.44%
# Epoch [82/100], Train Loss: 0.2241, Train Accuracy: 91.00%, Validation Loss: 0.3016, Validation Accuracy: 87.07%
# Epoch [83/100], Train Loss: 0.2248, Train Accuracy: 91.26%, Validation Loss: 0.3086, Validation Accuracy: 87.29%
# Epoch [84/100], Train Loss: 0.2254, Train Accuracy: 90.98%, Validation Loss: 0.3000, Validation Accuracy: 87.07%
# Epoch [85/100], Train Loss: 0.2334, Train Accuracy: 90.56%, Validation Loss: 0.3151, Validation Accuracy: 87.22%
# Epoch [86/100], Train Loss: 0.2245, Train Accuracy: 91.41%, Validation Loss: 0.3025, Validation Accuracy: 87.22%
# Epoch [87/100], Train Loss: 0.2287, Train Accuracy: 90.53%, Validation Loss: 0.3236, Validation Accuracy: 86.69%
# Epoch [88/100], Train Loss: 0.2251, Train Accuracy: 91.13%, Validation Loss: 0.3032, Validation Accuracy: 87.44%
# Epoch [89/100], Train Loss: 0.2285, Train Accuracy: 91.02%, Validation Loss: 0.2958, Validation Accuracy: 87.52%
# Epoch [90/100], Train Loss: 0.2237, Train Accuracy: 91.03%, Validation Loss: 0.2929, Validation Accuracy: 87.44%
# Epoch [91/100], Train Loss: 0.2271, Train Accuracy: 91.33%, Validation Loss: 0.2969, Validation Accuracy: 87.29%
# Epoch [92/100], Train Loss: 0.2281, Train Accuracy: 90.96%, Validation Loss: 0.2954, Validation Accuracy: 87.59%
# Epoch [93/100], Train Loss: 0.2249, Train Accuracy: 90.90%, Validation Loss: 0.3226, Validation Accuracy: 87.07%
# Epoch [94/100], Train Loss: 0.2267, Train Accuracy: 90.88%, Validation Loss: 0.2934, Validation Accuracy: 87.29%
# Epoch [95/100], Train Loss: 0.2278, Train Accuracy: 91.05%, Validation Loss: 0.3204, Validation Accuracy: 87.22%
# Epoch [96/100], Train Loss: 0.2251, Train Accuracy: 91.13%, Validation Loss: 0.3000, Validation Accuracy: 87.14%
# Epoch [97/100], Train Loss: 0.2255, Train Accuracy: 90.79%, Validation Loss: 0.2919, Validation Accuracy: 87.67%
# Epoch [98/100], Train Loss: 0.2242, Train Accuracy: 91.07%, Validation Loss: 0.3216, Validation Accuracy: 86.99%
# Epoch [99/100], Train Loss: 0.2244, Train Accuracy: 91.09%, Validation Loss: 0.2950, Validation Accuracy: 87.37%
# Epoch [100/100], Train Loss: 0.2236, Train Accuracy: 91.33%, Validation Loss: 0.2939, Validation Accuracy: 87.59%

# %%
torch.save(model.state_dict(), 'swin5e-5model.pth')

# %%
# Function to Evaluate Model on Any Dataset (Validation or Test)
def evaluate_model(model, data_loader):
    model.eval()
    y_true, y_pred_prob = [], []

    with torch.no_grad():
        for images, labels in data_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            probabilities = torch.sigmoid(outputs.logits)
            
            y_true.extend(labels.cpu().numpy())
            y_pred_prob.extend(probabilities.cpu().numpy())

    y_true = np.array(y_true)
    y_pred_prob = np.array(y_pred_prob)
    y_pred = (y_pred_prob >= 0.5).astype(int)
 # Compute Metrics
    cm = confusion_matrix(y_true, y_pred)
    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred)
    recall = recall_score(y_true, y_pred)  
    specificity = cm[0, 0] / (cm[0, 0] + cm[0, 1])  
    auc_score = roc_auc_score(y_true, y_pred_prob)

    # Print Results
    print(f"\nConfusion Matrix:\n{cm}")
    print(f"Accuracy: {accuracy:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"Recall (Sensitivity): {recall:.4f}")
    print(f"Specificity: {specificity:.4f}")
    print(f"AUC Score: {auc_score:.4f}")

    return y_true, y_pred_prob, cm, auc_score, accuracy, precision, recall, specificity

# Evaluate on Validation Set
print("\n Evaluating on Validation Set:")
evaluation_list = evaluate_model(model, val_dataloader)
# Out:
#  Evaluating on Validation Set:
#
# Confusion Matrix:
# [[823  59]
#  [106 342]]
# Accuracy: 0.8759
# Precision: 0.8529
# Recall (Sensitivity): 0.7634
# Specificity: 0.9331
# AUC Score: 0.9379

# %%
# Plot Confusion Matrix
y_true, y_pred_prob, cm, auc_score = evaluation_list[:4]

plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=["Negative", "Positive"], yticklabels=["Negative", "Positive"])
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")
plt.show()

# Plot ROC Curve
fpr, tpr, _ = roc_curve(y_true, y_pred_prob)
plt.figure(figsize=(6, 5))
plt.plot(fpr, tpr, label=f"AUC = {auc_score:.4f}", color="darkorange")
plt.plot([0, 1], [0, 1], linestyle="--", color="gray")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend()
plt.show()

# Plot Train_Val accuracy
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(train_accuracies, label='Train Accuracy')
plt.plot(val_accuracies, label='Val Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Plot Train_Val loss
plt.subplot(1, 2, 2)
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Val Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()
