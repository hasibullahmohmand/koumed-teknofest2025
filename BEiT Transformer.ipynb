# %%
import torch
from torch import nn, optim
from torch.utils.data import DataLoader
from torchvision import transforms
from torchvision.datasets import ImageFolder
from transformers import BeitForImageClassification
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, roc_auc_score, roc_curve
import seaborn as sns
import numpy as np

# %%
dataset_dir = '/kaggle/input/brainstroke2class/dataset'
test_dataset_dir = "/kaggle/input/brain-testset/testset"
torch.manual_seed(42)
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]) 
])

dataset = ImageFolder(root=dataset_dir, transform=transform)
test_dataset = ImageFolder(root=test_dataset_dir, transform=transform)
# Split the dataset into train and validation sets (80% training, 20% validation)
train_size = int(0.8 * len(dataset))
val_size = len(dataset) - train_size
train_dataset, val_dataset = torch.utils.data.random_split(dataset, [train_size, val_size])

# %%
print(dataset.class_to_idx)
print(test_dataset.class_to_idx)
# Out:
# {'inmeYokVeriSeti_PNG': 0, 'iskemiVeriSeti_PNG': 1}
# {'0_zero': 0, '1_one': 1}

# %%
train_dataloader = DataLoader(train_dataset, batch_size=16, shuffle=True)
val_dataloader = DataLoader(val_dataset, batch_size=16, shuffle=False)
test_dataloader = DataLoader(test_dataset, batch_size=16, shuffle=False)

# %%
model = BeitForImageClassification.from_pretrained(
    "microsoft/beit-base-patch16-224",
    num_labels=1,
    ignore_mismatched_sizes=True 
)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
if torch.cuda.device_count() > 1:
    print(f"Using {torch.cuda.device_count()} GPUs!")
    model = nn.DataParallel(model)
model.to(device)
# Out:
# config.json:   0%|          | 0.00/69.9k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/350M [00:00<?, ?B/s]
# Some weights of BeitForImageClassification were not initialized from the model checkpoint at microsoft/beit-base-patch16-224 and are newly initialized because the shapes did not match:
# - classifier.bias: found shape torch.Size([1000]) in the checkpoint and torch.Size([1]) in the model instantiated
# - classifier.weight: found shape torch.Size([1000, 768]) in the checkpoint and torch.Size([1, 768]) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Using 2 GPUs!
# DataParallel(
#   (module): BeitForImageClassification(
#     (beit): BeitModel(
#       (embeddings): BeitEmbeddings(
#         (patch_embeddings): BeitPatchEmbeddings(
#           (projection): Conv2d(3, 768, kernel_size=(16, 16), stride=(16, 16))
#         )
#         (dropout): Dropout(p=0.0, inplace=False)
#       )
#       (encoder): BeitEncoder(
#         (layer): ModuleList(
#           (0): BeitLayer(
#             (attention): BeitAttention(
#               (attention): BeitSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=False)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (relative_position_bias): BeitRelativePositionBias()
#               )
#               (output): BeitSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#             )
#             (intermediate): BeitIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BeitOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#             (layernorm_before): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (drop_path): Identity()
#             (layernorm_after): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           )
#           (1): BeitLayer(
#             (attention): BeitAttention(
#               (attention): BeitSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=False)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (relative_position_bias): BeitRelativePositionBias()
#               )
#               (output): BeitSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#             )
#             (intermediate): BeitIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BeitOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#             (layernorm_before): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (drop_path): BeitDropPath(p=0.00909090880304575)
#             (layernorm_after): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           )
#           (2): BeitLayer(
#             (attention): BeitAttention(
#               (attention): BeitSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=False)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (relative_position_bias): BeitRelativePositionBias()
#               )
#               (output): BeitSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#             )
#             (intermediate): BeitIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BeitOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#             (layernorm_before): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (drop_path): BeitDropPath(p=0.0181818176060915)
#             (layernorm_after): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           )
#           (3): BeitLayer(
#             (attention): BeitAttention(
#               (attention): BeitSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=False)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (relative_position_bias): BeitRelativePositionBias()
#               )
#               (output): BeitSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#             )
#             (intermediate): BeitIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BeitOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#             (layernorm_before): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (drop_path): BeitDropPath(p=0.027272727340459824)
#             (layernorm_after): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           )
#           (4): BeitLayer(
#             (attention): BeitAttention(
#               (attention): BeitSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=False)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (relative_position_bias): BeitRelativePositionBias()
#               )
#               (output): BeitSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#             )
#             (intermediate): BeitIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BeitOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#             (layernorm_before): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (drop_path): BeitDropPath(p=0.036363635212183)
#             (layernorm_after): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           )
#           (5): BeitLayer(
#             (attention): BeitAttention(
#               (attention): BeitSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=False)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (relative_position_bias): BeitRelativePositionBias()
#               )
#               (output): BeitSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#             )
#             (intermediate): BeitIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BeitOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#             (layernorm_before): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (drop_path): BeitDropPath(p=0.045454543083906174)
#             (layernorm_after): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           )
#           (6): BeitLayer(
#             (attention): BeitAttention(
#               (attention): BeitSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=False)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (relative_position_bias): BeitRelativePositionBias()
#               )
#               (output): BeitSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#             )
#             (intermediate): BeitIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BeitOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#             (layernorm_before): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (drop_path): BeitDropPath(p=0.054545458406209946)
#             (layernorm_after): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           )
#           (7): BeitLayer(
#             (attention): BeitAttention(
#               (attention): BeitSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=False)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (relative_position_bias): BeitRelativePositionBias()
#               )
#               (output): BeitSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#             )
#             (intermediate): BeitIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BeitOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#             (layernorm_before): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (drop_path): BeitDropPath(p=0.06363636255264282)
#             (layernorm_after): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           )
#           (8): BeitLayer(
#             (attention): BeitAttention(
#               (attention): BeitSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=False)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (relative_position_bias): BeitRelativePositionBias()
#               )
#               (output): BeitSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#             )
#             (intermediate): BeitIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BeitOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#             (layernorm_before): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (drop_path): BeitDropPath(p=0.0727272778749466)
#             (layernorm_after): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           )
#           (9): BeitLayer(
#             (attention): BeitAttention(
#               (attention): BeitSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=False)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (relative_position_bias): BeitRelativePositionBias()
#               )
#               (output): BeitSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#             )
#             (intermediate): BeitIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BeitOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#             (layernorm_before): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (drop_path): BeitDropPath(p=0.08181818574666977)
#             (layernorm_after): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           )
#           (10): BeitLayer(
#             (attention): BeitAttention(
#               (attention): BeitSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=False)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (relative_position_bias): BeitRelativePositionBias()
#               )
#               (output): BeitSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#             )
#             (intermediate): BeitIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BeitOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#             (layernorm_before): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (drop_path): BeitDropPath(p=0.09090909361839294)
#             (layernorm_after): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           )
#           (11): BeitLayer(
#             (attention): BeitAttention(
#               (attention): BeitSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=False)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#                 (relative_position_bias): BeitRelativePositionBias()
#               )
#               (output): BeitSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#             )
#             (intermediate): BeitIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BeitOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#             (layernorm_before): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (drop_path): BeitDropPath(p=0.10000000149011612)
#             (layernorm_after): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           )
#         )
#       )
#       (layernorm): Identity()
#       (pooler): BeitPooler(
#         (layernorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       )
#     )
#     (classifier): Linear(in_features=768, out_features=1, bias=True)
#   )
# )

# %%
for param in model.module.beit.parameters():
    param.requires_grad = False
for param in model.module.classifier.parameters():
    param.requires_grad = True

# %%
optimizer = optim.AdamW([
    {'params': model.module.beit.parameters(), 'lr': 1e-5},  
    {'params': model.module.classifier.parameters(), 'lr': 1e-3}  
], weight_decay=1e-4)  # L2 regularization
criterion = nn.BCEWithLogitsLoss()

# %%
train_losses = []
val_losses = []
train_accuracies = []
val_accuracies = []
epochs = 100
# Training loop
for epoch in range(epochs):
    model.train()  # Set model to training mode
    running_train_loss = 0.0
    correct_train = 0
    total_train = 0

    # Iterate through training data
    for inputs, labels in train_dataloader:
        inputs, labels = inputs.cuda(), labels.cuda()  # Move data to GPU

        # Zero the parameter gradients
        optimizer.zero_grad()

        # Forward pass
        outputs = model(inputs)
        loss = criterion(outputs.logits.squeeze(), labels.float())

        # Backward pass
        loss.backward()
        optimizer.step()

        # Track running loss
        running_train_loss += loss.item()

        # Track accuracy
        predicted = (torch.sigmoid(outputs.logits.squeeze()) > 0.5).long()
        total_train += labels.size(0)
        correct_train += (predicted == labels).sum().item()

    # Average training loss and accuracy for this epoch
    avg_train_loss = running_train_loss / len(train_dataloader)
    train_losses.append(avg_train_loss)
    train_accuracy = 100 * correct_train / total_train
    train_accuracies.append(train_accuracy)
    
    # Validation loop
    model.eval()  # Set model to evaluation mode
    running_val_loss = 0.0
    correct_val = 0
    total_val = 0

    with torch.no_grad():
        for inputs, labels in val_dataloader:
            inputs, labels = inputs.cuda(), labels.cuda()  # Move data to GPU

            # Forward pass
            outputs = model(inputs)
            loss = criterion(outputs.logits.squeeze(), labels.float())

            running_val_loss += loss.item()

            # Track validation accuracy
            predicted = (torch.sigmoid(outputs.logits.squeeze()) > 0.5).long()
            total_val += labels.size(0)
            correct_val += (predicted == labels).sum().item()

 # Average validation loss and accuracy for this epoch
    avg_val_loss = running_val_loss / len(val_dataloader)
    val_losses.append(avg_val_loss)
    val_accuracy = 100 * correct_val / total_val
    val_accuracies.append(val_accuracy)

    # Print epoch stats
    print(f'Epoch [{epoch+1}/{epochs}], '
          f'Train Loss: {avg_train_loss:.4f}, Train Accuracy: {train_accuracy:.2f}%, '
          f'Validation Loss: {avg_val_loss:.4f}, Validation Accuracy: {val_accuracy:.2f}%')
# Out:
# Epoch [1/100], Train Loss: 0.5575, Train Accuracy: 71.54%, Validation Loss: 0.4988, Validation Accuracy: 77.44%
# Epoch [2/100], Train Loss: 0.5012, Train Accuracy: 76.90%, Validation Loss: 0.4655, Validation Accuracy: 79.70%
# Epoch [3/100], Train Loss: 0.4717, Train Accuracy: 79.04%, Validation Loss: 0.4425, Validation Accuracy: 81.65%
# Epoch [4/100], Train Loss: 0.4617, Train Accuracy: 78.80%, Validation Loss: 0.4312, Validation Accuracy: 81.58%
# Epoch [5/100], Train Loss: 0.4473, Train Accuracy: 80.56%, Validation Loss: 0.4190, Validation Accuracy: 82.78%
# Epoch [6/100], Train Loss: 0.4456, Train Accuracy: 79.74%, Validation Loss: 0.4223, Validation Accuracy: 81.95%
# Epoch [7/100], Train Loss: 0.4390, Train Accuracy: 80.68%, Validation Loss: 0.4065, Validation Accuracy: 83.01%
# Epoch [8/100], Train Loss: 0.4327, Train Accuracy: 81.18%, Validation Loss: 0.4018, Validation Accuracy: 83.31%
# Epoch [9/100], Train Loss: 0.4285, Train Accuracy: 81.05%, Validation Loss: 0.3991, Validation Accuracy: 82.71%
# Epoch [10/100], Train Loss: 0.4173, Train Accuracy: 82.07%, Validation Loss: 0.3969, Validation Accuracy: 83.61%
# Epoch [11/100], Train Loss: 0.4209, Train Accuracy: 81.84%, Validation Loss: 0.3918, Validation Accuracy: 83.31%
# Epoch [12/100], Train Loss: 0.4200, Train Accuracy: 81.73%, Validation Loss: 0.3920, Validation Accuracy: 83.16%
# Epoch [13/100], Train Loss: 0.4125, Train Accuracy: 82.26%, Validation Loss: 0.3957, Validation Accuracy: 83.23%
# Epoch [14/100], Train Loss: 0.4148, Train Accuracy: 82.12%, Validation Loss: 0.3898, Validation Accuracy: 83.38%
# Epoch [15/100], Train Loss: 0.4057, Train Accuracy: 82.22%, Validation Loss: 0.3895, Validation Accuracy: 83.31%
# Epoch [16/100], Train Loss: 0.4135, Train Accuracy: 82.35%, Validation Loss: 0.3804, Validation Accuracy: 83.46%
# Epoch [17/100], Train Loss: 0.4134, Train Accuracy: 82.63%, Validation Loss: 0.3786, Validation Accuracy: 83.83%
# Epoch [18/100], Train Loss: 0.4016, Train Accuracy: 82.67%, Validation Loss: 0.3787, Validation Accuracy: 83.08%
# Epoch [19/100], Train Loss: 0.4037, Train Accuracy: 82.26%, Validation Loss: 0.3969, Validation Accuracy: 82.93%
# Epoch [20/100], Train Loss: 0.4009, Train Accuracy: 83.25%, Validation Loss: 0.3916, Validation Accuracy: 83.83%
# Epoch [21/100], Train Loss: 0.3920, Train Accuracy: 83.55%, Validation Loss: 0.3917, Validation Accuracy: 83.68%
# Epoch [22/100], Train Loss: 0.4010, Train Accuracy: 82.20%, Validation Loss: 0.3739, Validation Accuracy: 84.51%
# Epoch [23/100], Train Loss: 0.3976, Train Accuracy: 82.84%, Validation Loss: 0.3749, Validation Accuracy: 83.91%
# Epoch [24/100], Train Loss: 0.3905, Train Accuracy: 83.38%, Validation Loss: 0.3661, Validation Accuracy: 84.81%
# Epoch [25/100], Train Loss: 0.3934, Train Accuracy: 83.06%, Validation Loss: 0.3651, Validation Accuracy: 84.81%
# Epoch [26/100], Train Loss: 0.3930, Train Accuracy: 83.46%, Validation Loss: 0.3731, Validation Accuracy: 84.06%
# Epoch [27/100], Train Loss: 0.3867, Train Accuracy: 82.93%, Validation Loss: 0.3672, Validation Accuracy: 83.91%
# Epoch [28/100], Train Loss: 0.3926, Train Accuracy: 83.25%, Validation Loss: 0.3619, Validation Accuracy: 84.74%
# Epoch [29/100], Train Loss: 0.3930, Train Accuracy: 83.16%, Validation Loss: 0.3623, Validation Accuracy: 84.89%
# Epoch [30/100], Train Loss: 0.3951, Train Accuracy: 83.57%, Validation Loss: 0.3646, Validation Accuracy: 84.06%
# Epoch [31/100], Train Loss: 0.3884, Train Accuracy: 83.52%, Validation Loss: 0.3814, Validation Accuracy: 84.06%
# Epoch [32/100], Train Loss: 0.3836, Train Accuracy: 83.85%, Validation Loss: 0.3681, Validation Accuracy: 84.14%
# Epoch [33/100], Train Loss: 0.3786, Train Accuracy: 84.10%, Validation Loss: 0.3576, Validation Accuracy: 84.81%
# Epoch [34/100], Train Loss: 0.3877, Train Accuracy: 83.48%, Validation Loss: 0.3620, Validation Accuracy: 85.04%
# Epoch [35/100], Train Loss: 0.3775, Train Accuracy: 83.97%, Validation Loss: 0.3560, Validation Accuracy: 85.19%
# Epoch [36/100], Train Loss: 0.3809, Train Accuracy: 83.57%, Validation Loss: 0.3545, Validation Accuracy: 85.41%
# Epoch [37/100], Train Loss: 0.3828, Train Accuracy: 83.61%, Validation Loss: 0.3538, Validation Accuracy: 85.04%
# Epoch [38/100], Train Loss: 0.3785, Train Accuracy: 84.45%, Validation Loss: 0.3578, Validation Accuracy: 84.51%
# Epoch [39/100], Train Loss: 0.3783, Train Accuracy: 84.02%, Validation Loss: 0.3544, Validation Accuracy: 85.71%
# Epoch [40/100], Train Loss: 0.3826, Train Accuracy: 83.33%, Validation Loss: 0.3499, Validation Accuracy: 86.09%
# Epoch [41/100], Train Loss: 0.3797, Train Accuracy: 84.25%, Validation Loss: 0.3496, Validation Accuracy: 86.09%
# Epoch [42/100], Train Loss: 0.3836, Train Accuracy: 83.52%, Validation Loss: 0.3520, Validation Accuracy: 85.41%
# Epoch [43/100], Train Loss: 0.3786, Train Accuracy: 84.17%, Validation Loss: 0.3484, Validation Accuracy: 85.94%
# Epoch [44/100], Train Loss: 0.3861, Train Accuracy: 84.02%, Validation Loss: 0.3532, Validation Accuracy: 85.26%
# Epoch [45/100], Train Loss: 0.3726, Train Accuracy: 84.19%, Validation Loss: 0.3479, Validation Accuracy: 85.41%
# Epoch [46/100], Train Loss: 0.3712, Train Accuracy: 84.10%, Validation Loss: 0.3488, Validation Accuracy: 85.34%
# Epoch [47/100], Train Loss: 0.3665, Train Accuracy: 84.08%, Validation Loss: 0.3492, Validation Accuracy: 85.71%
# Epoch [48/100], Train Loss: 0.3650, Train Accuracy: 84.17%, Validation Loss: 0.3515, Validation Accuracy: 85.04%
# Epoch [49/100], Train Loss: 0.3755, Train Accuracy: 84.12%, Validation Loss: 0.3512, Validation Accuracy: 85.19%
# Epoch [50/100], Train Loss: 0.3732, Train Accuracy: 84.44%, Validation Loss: 0.3445, Validation Accuracy: 86.17%
# Epoch [51/100], Train Loss: 0.3758, Train Accuracy: 84.15%, Validation Loss: 0.3858, Validation Accuracy: 83.83%
# Epoch [52/100], Train Loss: 0.3679, Train Accuracy: 84.15%, Validation Loss: 0.3472, Validation Accuracy: 85.49%
# Epoch [53/100], Train Loss: 0.3690, Train Accuracy: 84.40%, Validation Loss: 0.3488, Validation Accuracy: 85.19%
# Epoch [54/100], Train Loss: 0.3699, Train Accuracy: 84.51%, Validation Loss: 0.3464, Validation Accuracy: 85.49%
# Epoch [55/100], Train Loss: 0.3731, Train Accuracy: 84.32%, Validation Loss: 0.3480, Validation Accuracy: 85.26%
# Epoch [56/100], Train Loss: 0.3691, Train Accuracy: 84.55%, Validation Loss: 0.3414, Validation Accuracy: 85.86%
# Epoch [57/100], Train Loss: 0.3632, Train Accuracy: 84.49%, Validation Loss: 0.3412, Validation Accuracy: 85.79%
# Epoch [58/100], Train Loss: 0.3655, Train Accuracy: 84.55%, Validation Loss: 0.3401, Validation Accuracy: 85.71%
# Epoch [59/100], Train Loss: 0.3730, Train Accuracy: 84.45%, Validation Loss: 0.3399, Validation Accuracy: 86.02%
# Epoch [60/100], Train Loss: 0.3662, Train Accuracy: 84.45%, Validation Loss: 0.3404, Validation Accuracy: 85.64%
# Epoch [61/100], Train Loss: 0.3645, Train Accuracy: 84.64%, Validation Loss: 0.3407, Validation Accuracy: 85.86%
# Epoch [62/100], Train Loss: 0.3656, Train Accuracy: 84.38%, Validation Loss: 0.3598, Validation Accuracy: 84.81%
# Epoch [63/100], Train Loss: 0.3653, Train Accuracy: 84.32%, Validation Loss: 0.3516, Validation Accuracy: 85.04%
# Epoch [64/100], Train Loss: 0.3630, Train Accuracy: 84.96%, Validation Loss: 0.3374, Validation Accuracy: 86.47%
# Epoch [65/100], Train Loss: 0.3630, Train Accuracy: 85.02%, Validation Loss: 0.3411, Validation Accuracy: 85.56%
# Epoch [66/100], Train Loss: 0.3659, Train Accuracy: 84.23%, Validation Loss: 0.3385, Validation Accuracy: 85.94%
# Epoch [67/100], Train Loss: 0.3680, Train Accuracy: 84.08%, Validation Loss: 0.3371, Validation Accuracy: 86.24%
# Epoch [68/100], Train Loss: 0.3626, Train Accuracy: 84.64%, Validation Loss: 0.3375, Validation Accuracy: 85.79%
# Epoch [69/100], Train Loss: 0.3672, Train Accuracy: 83.85%, Validation Loss: 0.3357, Validation Accuracy: 86.17%
# Epoch [70/100], Train Loss: 0.3643, Train Accuracy: 84.44%, Validation Loss: 0.3413, Validation Accuracy: 86.24%
# Epoch [71/100], Train Loss: 0.3655, Train Accuracy: 84.98%, Validation Loss: 0.3368, Validation Accuracy: 86.32%
# Epoch [72/100], Train Loss: 0.3599, Train Accuracy: 84.77%, Validation Loss: 0.3469, Validation Accuracy: 85.94%
# Epoch [73/100], Train Loss: 0.3691, Train Accuracy: 84.76%, Validation Loss: 0.3346, Validation Accuracy: 86.39%
# Epoch [74/100], Train Loss: 0.3597, Train Accuracy: 84.49%, Validation Loss: 0.3342, Validation Accuracy: 85.86%
# Epoch [75/100], Train Loss: 0.3657, Train Accuracy: 84.49%, Validation Loss: 0.3364, Validation Accuracy: 86.02%
# Epoch [76/100], Train Loss: 0.3580, Train Accuracy: 84.62%, Validation Loss: 0.3336, Validation Accuracy: 85.94%
# Epoch [77/100], Train Loss: 0.3661, Train Accuracy: 84.38%, Validation Loss: 0.3370, Validation Accuracy: 86.39%
# Epoch [78/100], Train Loss: 0.3553, Train Accuracy: 84.85%, Validation Loss: 0.3347, Validation Accuracy: 86.02%
# Epoch [79/100], Train Loss: 0.3637, Train Accuracy: 85.04%, Validation Loss: 0.3341, Validation Accuracy: 85.94%
# Epoch [80/100], Train Loss: 0.3571, Train Accuracy: 85.08%, Validation Loss: 0.3320, Validation Accuracy: 86.24%
# Epoch [81/100], Train Loss: 0.3550, Train Accuracy: 85.04%, Validation Loss: 0.3392, Validation Accuracy: 85.71%
# Epoch [82/100], Train Loss: 0.3627, Train Accuracy: 84.64%, Validation Loss: 0.3339, Validation Accuracy: 86.24%
# Epoch [83/100], Train Loss: 0.3657, Train Accuracy: 84.36%, Validation Loss: 0.3314, Validation Accuracy: 86.54%
# Epoch [84/100], Train Loss: 0.3543, Train Accuracy: 85.17%, Validation Loss: 0.3396, Validation Accuracy: 85.64%
# Epoch [85/100], Train Loss: 0.3591, Train Accuracy: 85.39%, Validation Loss: 0.3378, Validation Accuracy: 85.86%
# Epoch [86/100], Train Loss: 0.3580, Train Accuracy: 85.11%, Validation Loss: 0.3426, Validation Accuracy: 85.94%
# Epoch [87/100], Train Loss: 0.3594, Train Accuracy: 85.17%, Validation Loss: 0.3404, Validation Accuracy: 85.49%
# Epoch [88/100], Train Loss: 0.3605, Train Accuracy: 84.85%, Validation Loss: 0.3315, Validation Accuracy: 86.24%
# Epoch [89/100], Train Loss: 0.3555, Train Accuracy: 84.85%, Validation Loss: 0.3299, Validation Accuracy: 86.62%
# Epoch [90/100], Train Loss: 0.3555, Train Accuracy: 85.00%, Validation Loss: 0.3327, Validation Accuracy: 86.02%
# Epoch [91/100], Train Loss: 0.3615, Train Accuracy: 84.89%, Validation Loss: 0.3285, Validation Accuracy: 86.32%
# Epoch [92/100], Train Loss: 0.3497, Train Accuracy: 85.39%, Validation Loss: 0.3394, Validation Accuracy: 85.86%
# Epoch [93/100], Train Loss: 0.3549, Train Accuracy: 85.15%, Validation Loss: 0.3311, Validation Accuracy: 86.17%
# Epoch [94/100], Train Loss: 0.3522, Train Accuracy: 84.92%, Validation Loss: 0.3282, Validation Accuracy: 86.24%
# Epoch [95/100], Train Loss: 0.3597, Train Accuracy: 85.19%, Validation Loss: 0.3333, Validation Accuracy: 86.17%
# Epoch [96/100], Train Loss: 0.3497, Train Accuracy: 85.49%, Validation Loss: 0.3401, Validation Accuracy: 85.56%
# Epoch [97/100], Train Loss: 0.3557, Train Accuracy: 85.04%, Validation Loss: 0.3446, Validation Accuracy: 85.71%
# Epoch [98/100], Train Loss: 0.3584, Train Accuracy: 85.23%, Validation Loss: 0.3262, Validation Accuracy: 86.32%
# Epoch [99/100], Train Loss: 0.3541, Train Accuracy: 84.91%, Validation Loss: 0.3268, Validation Accuracy: 86.32%
# Epoch [100/100], Train Loss: 0.3525, Train Accuracy: 85.24%, Validation Loss: 0.3310, Validation Accuracy: 86.02%

# %%
torch.save(model.state_dict(), 'BEit1e-5model.pth')

# %%
# Function to Evaluate Model on Any Dataset (Validation or Test)
def evaluate_model(model, data_loader):
    model.eval()
    y_true, y_pred_prob = [], []

    with torch.no_grad():
        for images, labels in data_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            probabilities = torch.sigmoid(outputs.logits)
            
            y_true.extend(labels.cpu().numpy())
            y_pred_prob.extend(probabilities.cpu().numpy())

    y_true = np.array(y_true)
    y_pred_prob = np.array(y_pred_prob)
    y_pred = (y_pred_prob >= 0.5).astype(int)
 # Compute Metrics
    cm = confusion_matrix(y_true, y_pred)
    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred)
    recall = recall_score(y_true, y_pred)  
    specificity = cm[0, 0] / (cm[0, 0] + cm[0, 1])  
    auc_score = roc_auc_score(y_true, y_pred_prob)

    # Print Results
    print(f"\nConfusion Matrix:\n{cm}")
    print(f"Accuracy: {accuracy:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"Recall (Sensitivity): {recall:.4f}")
    print(f"Specificity: {specificity:.4f}")
    print(f"AUC Score: {auc_score:.4f}")

    return y_true, y_pred_prob, cm, auc_score, accuracy, precision, recall, specificity

# %%
# Plot Confusion Matrix
def draw_graph(y_true, y_pred_prob, cm, auc_score):
    plt.figure(figsize=(6, 5))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=["Negative", "Positive"], yticklabels=["Negative", "Positive"])
    plt.xlabel("Predicted Label")
    plt.ylabel("True Label")
    plt.title("Confusion Matrix")
    plt.show()
    
    # Plot ROC Curve
    fpr, tpr, _ = roc_curve(y_true, y_pred_prob)
    plt.figure(figsize=(6, 5))
    plt.plot(fpr, tpr, label=f"AUC = {auc_score:.4f}", color="darkorange")
    plt.plot([0, 1], [0, 1], linestyle="--", color="gray")
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.title("ROC Curve")
    plt.legend()
    plt.show()
    
    # Plot Train_Val accuracy
    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    plt.plot(train_accuracies, label='Train Accuracy')
    plt.plot(val_accuracies, label='Val Accuracy')
    plt.title('Model Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    
    # Plot Train_Val loss
    plt.subplot(1, 2, 2)
    plt.plot(train_losses, label='Train Loss')
    plt.plot(val_losses, label='Val Loss')
    plt.title('Model Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    
    plt.tight_layout()
    plt.show()

# %%
print("\n Evaluating on Validation Set:")
evaluation_list = evaluate_model(model, val_dataloader)
y_true, y_pred_prob, cm, auc_score = evaluation_list[:4]
draw_graph(y_true, y_pred_prob, cm, auc_score)
print("\n Ealuating on Test Set:")
test_evaluation_list = evaluate_model(model, test_dataloader)
t_y_true, t_y_pred_prob, t_cm, t_auc_score = test_evaluation_list[:4]
draw_graph(t_y_true, t_y_pred_prob, t_cm, t_auc_score)
# Out:
#  Evaluating on Validation Set:
#
# Confusion Matrix:
# [[844  38]
#  [148 300]]
# Accuracy: 0.8602
# Precision: 0.8876
# Recall (Sensitivity): 0.6696
# Specificity: 0.9569
# AUC Score: 0.9243
#  Ealuating on Test Set:
#
# Confusion Matrix:
# [[117  13]
#  [ 23  47]]
# Accuracy: 0.8200
# Precision: 0.7833
# Recall (Sensitivity): 0.6714
# Specificity: 0.9000
# AUC Score: 0.8751
